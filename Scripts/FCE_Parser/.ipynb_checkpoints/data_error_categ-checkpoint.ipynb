# %%
import numpy as np
import pandas as pd

# %%
df_data = pd.read_csv("../data/fce_txt/all_converted.csv")

# %%
df_data
# Out:
#                                                incorrect  \
# 0                                            Dear Helen.
# 1      I have received your letter which is make me h...
# 2      I have received your letter which is make me h...
# 3      I have received your letter which is make me h...
# 4      I have received your letter which is make me h...
# ...                                                  ...
# 44517  You have been presented  some causes why shopp...
# 44518  You have been presented  some causes why shopp...
# 44519  You have been presented  some causes why shopp...
# 44520  You have been presented  some causes why shopp...
# 44521  You have been presented  some causes why shopp...
#
#                                                  correct  \
# 0                                            Dear Helen,
# 1      I have received your letter, which  makes me h...
# 2      I have received your letter, which  makes me h...
# 3      I have received your letter, which  makes me h...
# 4      I have received your letter, which  makes me h...
# ...                                                  ...
# 44517  You have been presented with some reasons why ...
# 44518  You have been presented with some reasons why ...
# 44519  You have been presented with some reasons why ...
# 44520  You have been presented with some reasons why ...
# 44521  You have been presented with some reasons why ...
#
#                                                    error
# 0      {'tag': 'RP', 'incorrect': '.', 'correct': ','...
# 1      {'tag': 'MP', 'incorrect': '', 'correct': ',',...
# 2      {'tag': 'UV', 'incorrect': 'is', 'correct': ''...
# 3      {'tag': 'AGV', 'incorrect': 'make', 'correct':...
# 4      {'tag': 'MT', 'incorrect': 'The', 'correct': '...
# ...                                                  ...
# 44517  {'tag': 'MT', 'incorrect': '', 'correct': 'wit...
# 44518  {'tag': 'RN', 'incorrect': 'causes', 'correct'...
# 44519  {'tag': 'R', 'incorrect': 'behaviour to make m...
# 44520  {'tag': 'RV', 'incorrect': 'act', 'correct': '...
# 44521  {'tag': 'RT', 'incorrect': 'as', 'correct': 'l...
#
# [44522 rows x 3 columns]

# %%
df_error_cat = pd.read_csv("error_categories.csv")

# %%
df_error_cat
# Out:
#    Error Code Level 1 Category Level 2 Category Level 3 Category  \
# 0          AG        Agreement     Misselection          Grammar
# 1         AGA        Agreement     Misselection          Grammar
# 2         AGD        Agreement     Misselection          Grammar
# 3         AGN        Agreement     Misselection          Grammar
# 4         AGQ        Agreement     Misselection          Grammar
# ..        ...              ...              ...              ...
# 71         UT     content-word         omission            lexis
# 72         UV    function word         omission            lexis
# 73         UY    function word         omission            lexis
# 74          W       word order      misordering          Grammar
# 75          X         negation              NaN          grammar
#
#    Category Code  Frequency (as per image from google drive)
# 0             GM                                        1645
# 1             GM                                       11537
# 2             GM                                        8813
# 3             GM                                       35605
# 4             GM                                        1427
# ..           ...                                         ...
# 71            LX                                       56246
# 72            LX                                       24002
# 73            LX                                       16998
# 74            GM                                       76586
# 75            GM                                        4180
#
# [76 rows x 6 columns]

# %%
error_map = dict(zip(df_error_cat["Error Code"],df_error_cat["Category Code"]))
error_map
# Out:
# {'AG': 'GM',
#  'AGA': 'GM',
#  'AGD': 'GM',
#  'AGN': 'GM',
#  'AGQ': 'GM',
#  'AGV': 'GM',
#  'AS': 'GM',
#  'CD': 'GM',
#  'CE': 'DS',
#  'CL': 'SM',
#  'CN': 'GM',
#  'CQ': 'GM',
#  'DA': 'GM',
#  'DC': 'GM',
#  'DD': 'GM',
#  'DI': 'GM',
#  'DJ': 'GM',
#  'DN': 'GM',
#  'DQ': 'GM',
#  'DT': 'GM',
#  'DV': 'GM',
#  'DY': 'GM',
#  'FA': 'GM',
#  'FD': 'GM',
#  'FJ': 'GM',
#  'FN': 'GM',
#  'FQ': 'GM',
#  'FV': 'GM',
#  'FY': 'GM',
#  'IA': 'GM',
#  'ID': 'SM',
#  'IJ': 'GM',
#  'IN': 'GM',
#  'IQ': 'GM',
#  'IV': 'GM',
#  'IY': 'GM',
#  'L': 'DS',
#  'M': 'LX',
#  'MA': 'LX',
#  'MC': 'LX',
#  'MD': 'LX',
#  'MJ': 'LX',
#  'MN': 'LX',
#  'MP': 'OT',
#  'MQ': 'LX',
#  'MT': 'LX',
#  'MV': 'LX',
#  'MY': 'LX',
#  'R': 'LX',
#  'RA': 'LX',
#  'RC': 'LX',
#  'RD': 'LX',
#  'RJ': 'LX',
#  'RN': 'LX',
#  'RP': 'LX',
#  'RQ': 'LX',
#  'RT': 'LX',
#  'RV': 'LX',
#  'RY': 'LX',
#  'S': 'OT',
#  'SA': 'OT',
#  'SX': 'OT',
#  'TV': 'GM',
#  'U': 'LX',
#  'UA': 'LX',
#  'UC': 'LX',
#  'UD': 'LX',
#  'UJ': 'LX',
#  'UN': 'LX',
#  'UP': 'OT',
#  'UQ': 'LX',
#  'UT': 'LX',
#  'UV': 'LX',
#  'UY': 'LX',
#  'W': 'GM',
#  'X': 'GM'}

# %%
df_data['error']
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-29-a0f0685ba26a> in <module>
# ----> 1 dict(df_data['error'][0])
#
# ValueError: dictionary update sequence element #0 has length 1; 2 is required

# %%
df_data.loc[df['error']]
